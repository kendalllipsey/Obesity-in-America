# %%
# importing modules
import pandas as pd
import matplotlib.pyplot as plt

#https://www.ers.usda.gov/data-products/food-access-research-atlas/download-the-data/
access = pd.read_csv('./obeseaccess.csv')

access.head()
# Out:
#    FIPS State   County  PCT_LACCESS_POP15  PCT_LACCESS_LOWI10  \
# 0  1001    AL  Autauga          32.062255            9.793530
# 1  1003    AL  Baldwin          16.767489            5.460261
# 2  1005    AL  Barbour          22.105560           11.420316
# 3  1007    AL     Bibb           4.230324            2.144661
# 4  1009    AL   Blount           6.497380            1.062468
#
#    PCT_LACCESS_HHNV15  Unnamed: 6  Unnamed: 7
# 0            3.351332         NaN         NaN
# 1            1.905114         NaN         NaN
# 2            4.329378         NaN         NaN
# 3            2.821427         NaN         NaN
# 4            3.336414         NaN         NaN

# %%
#ec[(ec.Date >= '2014') & (ec.Date < '2015')]

NCaccess = access[(access.State=='NC')]
NCaccess.head()
# Out:
#        FIPS State     County  PCT_LACCESS_POP15  PCT_LACCESS_LOWI10  \
# 1890  37001    NC   Alamance          22.921531           11.302387
# 1891  37003    NC  Alexander           6.530454            2.270292
# 1892  37005    NC  Alleghany           3.861072            1.362736
# 1893  37007    NC      Anson           6.556922            3.062507
# 1894  37009    NC       Ashe           5.247664            2.489243
#
#       PCT_LACCESS_HHNV15  Unnamed: 6  Unnamed: 7
# 1890            2.441777         NaN         NaN
# 1891            3.086339         NaN         NaN
# 1892            5.271229         NaN         NaN
# 1893            6.393951         NaN         NaN
# 1894            5.577290         NaN         NaN

# %%
NCobesity =pd.read_csv('./NCobesity.csv')
#from https://www.countyhealthrankings.org/app/north-carolina/2016/measure/factors/11/data
NCobesity.head()
# Out:
#        Place  Unnamed: 1 % Obese Error Margin  Z-Score
# 0   Alamance         NaN     34%       30-38%     0.64
# 1  Alexander         NaN     33%       27-40%     0.47
# 2  Alleghany         NaN     26%       20-32%    -1.27
# 3      Anson         NaN     35%       28-42%     0.83
# 4       Ashe         NaN     26%       21-32%    -1.10

# %%
NCobesity.columns=['County', 'Empty', '% Obese', 'Error Margin', 'Z-Score']
NCobesity.head()
# Out:
#       County  Empty % Obese Error Margin  Z-Score
# 0   Alamance    NaN     34%       30-38%     0.64
# 1  Alexander    NaN     33%       27-40%     0.47
# 2  Alleghany    NaN     26%       20-32%    -1.27
# 3      Anson    NaN     35%       28-42%     0.83
# 4       Ashe    NaN     26%       21-32%    -1.10

# %%
NCmerge = pd.merge(NCobesity,NCaccess)
NCmerge.head()
# Out:
#       County  Empty % Obese Error Margin  Z-Score   FIPS State  \
# 0   Alamance    NaN     34%       30-38%     0.64  37001    NC
# 1  Alexander    NaN     33%       27-40%     0.47  37003    NC
# 2  Alleghany    NaN     26%       20-32%    -1.27  37005    NC
# 3      Anson    NaN     35%       28-42%     0.83  37007    NC
# 4       Ashe    NaN     26%       21-32%    -1.10  37009    NC
#
#    PCT_LACCESS_POP15  PCT_LACCESS_LOWI10  PCT_LACCESS_HHNV15  Unnamed: 6  \
# 0          22.921531           11.302387            2.441777         NaN
# 1           6.530454            2.270292            3.086339         NaN
# 2           3.861072            1.362736            5.271229         NaN
# 3           6.556922            3.062507            6.393951         NaN
# 4           5.247664            2.489243            5.577290         NaN
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
'''
PCT_LACCESS_POP15 is :Population, low access to store (%), 2015
PCT_LACCESS_LOWI15 is : Low income & low access to store (%), 2015
PCT_LACCESS_HHNV15 is : Households, no car & low access to store (%), 2015
'''
# Out:
# '\nPCT_LACCESS_POP15 is :Population, low access to store (%), 2015\nPCT_LACCESS_LOWI15 is : Low income & low access to store (%), 2015\nPCT_LACCESS_HHNV15 is : Households, no car & low access to store (%), 2015\n'

# %%
USAobese = pd.read_csv('./USAobesetime.csv')
#from https://ourworldindata.org/obesity
USAobese = USAobese[(USAobese.Code=='USA')]
USAobese.columns=['Entity', 'Code', 'Year', 'pctobese']
USAobese.head()
# Out:
#              Entity Code  Year  pctobese
# 7896  United States  USA  1975      11.9
# 7897  United States  USA  1976      12.2
# 7898  United States  USA  1977      12.6
# 7899  United States  USA  1978      13.0
# 7900  United States  USA  1979      13.3

# %%
import seaborn as sns
# This makes plots appear in the notebook
# %matplotlib inline

# Plot yearly proportion of deaths at the two clinics
fig, ax = plt.subplots()
ax.plot(USAobese.Year, USAobese.pctobese, label='Percentage of Population Obese')


# add legends
leg = ax.legend()

# add x and y labels
ax.set_xlabel('Year')
ax.set_ylabel('Percentage of US Population Obese')
# Out:
# Text(0, 0.5, 'Percentage of US Population Obese')

# %%
'''
Couldn't get above to work in this Jupyter, version?
Added code to 502 09Cartopy at bottom. 
'''

# %%
import cartopy

import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from cartopy.feature import NaturalEarthFeature, LAND, COASTLINE, BORDERS
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader
import matplotlib.pyplot as plt
import cartopy

import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from cartopy.feature import NaturalEarthFeature, LAND, COASTLINE, BORDERS
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# %%
# Set the size to 12, 20
fig, ax = plt.subplots(figsize=(12, 14), subplot_kw=dict(projection=ccrs.PlateCarree()))
ax.set_extent([-85, -75, 33, 38])

# display land and coastline
ax.add_feature(LAND)       

# Do not show x labels on the top of the graph   #if don't disable, see the labels on both the top and bottom 
gl.xlabels_top = False

# Do not show y labels on the right side of the graph
gl.ylabels_right = False

# Apply the lat and long formatter
gl.xformatter = LONGITUDE_FORMATTER               
gl.yformatter = LATITUDE_FORMATTER

# State borders
states = NaturalEarthFeature(category='cultural', scale='50m', facecolor='none',
                             name='admin_1_states_provinces_shp') #add another shape file. Cartopy doesnt provide this. 
ax.add_feature(states, edgecolor='gray')

# display the country border lines
ax.add_feature(BORDERS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e94b8d379646> in <module>
#       8
#       9 # Do not show x labels on the top of the graph   #if don't disable, see the labels on both the top and bottom
# ---> 10 gl.xlabels_top = False
#      11
#      12 # Do not show y labels on the right side of the graph
#
# NameError: name 'gl' is not defined
